# %%
pip install datasets
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from datasets import load_dataset
dataset = load_dataset("aida-ugent/JobHop")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# c:\Users\suyas\anaconda3\lib\site-packages\huggingface_hub\file_download.py:140: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\suyas\.cache\huggingface\hub\datasets--aida-ugent--JobHop. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# JobHop_train.csv:   0%|          | 0.00/380M [00:00<?, ?B/s]
# ...

# %%
import pandas as pd
# Show available splits
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['person_id', 'matched_label', 'matched_description', 'matched_code', 'start_date', 'end_date', 'university_studies'],
#         num_rows: 1341832
#     })
#     validation: Dataset({
#         features: ['person_id', 'matched_label', 'matched_description', 'matched_code', 'start_date', 'end_date', 'university_studies'],
#         num_rows: 167945
#     })
#     test: Dataset({
#         features: ['person_id', 'matched_label', 'matched_description', 'matched_code', 'start_date', 'end_date', 'university_studies'],
#         num_rows: 167924
#     })
# })

# %%
df = dataset['train'].to_pandas()

print("\n===== First 5 rows =====")
print(df.head())

print("\n===== Columns =====")
print(df.columns)

print("\n===== Dataset Info =====")
print(df.info())
# Out:
# ===== First 5 rows =====
#    person_id                            matched_label  \
# 0          0                         resource manager
# 1          0                health and safety officer
# 2          0                     integration engineer
# 3          0                        programme manager
# 4          0  product development engineering drafter
#
#                                  matched_description matched_code start_date  \
# 0  Resource managers manage resources for all pot...     1324.8.3    Q1 2016
# 1  Health and safety officers execute plans for t...       2263.3    Q1 2017
# 2  Integration engineers develop and implement so...      2511.17    Q1 2013
# 3  Programme managers coordinate and oversee seve...       1213.4    Q2 2012
# 4  Product development engineering drafters desig...    3118.3.12    Q1 2011
#
#   end_date  university_studies
# 0  Q2 2019                True
# 1  Q2 2019                True
# 2  Q1 2016                True
# ...

# %%
df.to_csv("jobhop_train.csv", index=False)
print("\nSaved jobhop_train.csv ✅")
# Out:
# Saved jobhop_train.csv ✅
